# %% [markdown]
# <a href="https://colab.research.google.com/github/RicardoV1e1r4/Processamento_de_Sinais_I/blob/main/praticas/pratica02/Python/Exe1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Para umsinal x(t) = cos(2πft) amostrado com fs = 44.1 kHz, faça o que se pede nos itens abaixo:

# %% [markdown]
# ### (a) Utilizando a função calculate_spectrum(), calcule o espectro de x(t) para f ∈ {500,5000,10000,50000} Hz.

# %% [markdown]
# ### (b) Comente os resultados obtidos.
